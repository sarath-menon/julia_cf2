# %%
import Pkg;Pkg.activate(@__DIR__);Pkg.instantiate();

# %%
using DSP
using GLMakie
using PyCall
using CSV
using DataFrames
using Accessors
using DataStructures

using BenchmarkTools

using Revise
import julia_cf2

# %% [markdown]
# ## Load data

# %%
df = CSV.read("./data/gyro_unfiltered.csv", DataFrame);
# print(df)

gyro_unfiltered_x = df.gyro_unfiltered_x;

# %% [markdown]
# # Design Chebushev filter

# %%
ripple = 3 # max passband ripple in dB
f_s = 1000 # sampling time [hz]
f_c = 80 # cutoff frequency [hz]
m = 4 # filter order

responsetype = Lowpass(f_c; fs=f_s)
designmethod = Chebyshev1(m,ripple )

chebyshev_filter = digitalfilter(responsetype, designmethod)
H, w_normalized = freqresp(chebyshev_filter)

w = w_normalized * f_s
mag = abs.(H)
mag_dB = julia_cf2.normal_to_dB(mag)
w_hz = julia_cf2.rad_per_sample_to_hz(w)

f = Figure()
ax1 = Axis(f[1, 1])
lines!(ax1, w_hz, mag)
vlines!(ax1, [f_c], color=:red)

display(f)
# Out:
# GLMakie.Screen(...)

# %% [markdown]
# ## Apply filter

# %%
gyro_filtered_x = filt(chebyshev_filter, gyro_unfiltered_x)

f = Figure()

ax1 = Axis(f[1, 1], title = "Scatter plot", xlabel = "time", ylabel = "Amplitude")
ax2 = Axis(f[2, 1], xlabel = "Normalized frequency", ylabel = "Power")

lines!(ax1, df.timestamp, gyro_unfiltered_x)
lines!(ax1, df.timestamp, gyro_filtered_x)

# plot periodogram
gyro_unfiltered_x_pg = welch_pgram(gyro_unfiltered_x);
gyro_filtered_x_pg = welch_pgram(gyro_filtered_x);

# f = Figure()


lines!(ax2, gyro_unfiltered_x_pg.freq, gyro_unfiltered_x_pg.power)
lines!(ax2, gyro_filtered_x_pg.freq, gyro_filtered_x_pg.power)
display(f)
# Out:
# GLMakie.Screen(...)

# %% [markdown]
# ## CMSIS DSP

# %%
sos = convert(SecondOrderSections, digitalfilter(responsetype, designmethod));
sos.biquads
# Out:
# 2-element Vector{Biquad{:z, Float64}}:
#  Biquad{:z, Float64}(1.0, 2.0, 1.0, -1.7649945303458097, 0.8111980508344275)
#  Biquad{:z, Float64}(1.0, 2.0, 1.0, -1.704866789708997, 0.9207156133757171)

# %%
# get second order sections 
sos = convert(SecondOrderSections, digitalfilter(responsetype, designmethod));

n_sections = size(sos.biquads,1)
println("No of sections: ", n_sections)

sos_cmsis = sos

# flip the sign of a coefficients 
sos_cmsis = @set sos_cmsis.biquads[1].a1 = -sos.biquads[1].a1;
sos_cmsis = @set sos_cmsis.biquads[1].a2 = -sos.biquads[1].a2;
sos_cmsis = @set sos_cmsis.biquads[2].a1 = -sos.biquads[2].a1;
sos_cmsis = @set sos_cmsis.biquads[2].a2 = -sos.biquads[2].a2;

# arrange coefficients in format required by CMSIS-DSP
coeff = [
        sos_cmsis.biquads[1].b0 * sos.g
        sos_cmsis.biquads[1].b1 * sos.g
        sos_cmsis.biquads[1].b2 * sos.g
        sos_cmsis.biquads[1].a1 
        sos_cmsis.biquads[1].a2 
        sos_cmsis.biquads[2].b0 
        sos_cmsis.biquads[2].b1
        sos_cmsis.biquads[2].b2 
        sos_cmsis.biquads[2].a1 
        sos_cmsis.biquads[2].a2 
        ];
# Out:
# No of sections: 2

# %%
cmsisdsp = pyimport("cmsisdsp")

# convert input data to float32
gyro_unfiltered_x_f32 = convert(Vector{Float32}, gyro_unfiltered_x)

# instance of fixed-point Biquad cascade filter
biquadf32 = cmsisdsp.arm_biquad_casd_df1_inst_f32()

# state array to initialize instance
numStages=n_sections
state2::Vector{Float32} = zeros(numStages*4)

# convert filter coeff to f32 format
coeff_f32_ = convert(Vector{Float32}, coeff )

# error checking for coefficient matrix shape
@assert size(coeff_f32_,1) == 5*numStages

# error checking for coefficient matrix shape
@assert size(state2,1) == 4*numStages

# initialize filter
cmsisdsp.arm_biquad_cascade_df1_init_f32(biquadf32,numStages,coeff_f32_,state2)

#  apply filter 
gyro_filtered_cmsis_f32_x = cmsisdsp.arm_biquad_cascade_df1_f32(biquadf32, gyro_unfiltered_x_f32);

# %%
f = Figure()

ax1 = Axis(f[1, 1], title = "Scatter plot", xlabel = "time", ylabel = "Amplitude")
ax2 = Axis(f[2, 1], xlabel = "Normalized frequency", ylabel = "Power")

lines!(ax1, df.timestamp, gyro_unfiltered_x)
lines!(ax1, df.timestamp, gyro_filtered_cmsis_f32_x)

# plot periodogram
gyro_unfiltered_x_pg = welch_pgram(gyro_unfiltered_x);
gyro_filtered_cmsis_x_pg = welch_pgram(gyro_filtered_cmsis_f32_x);

lines!(ax2, gyro_unfiltered_x_pg.freq, gyro_unfiltered_x_pg.power)
lines!(ax2, gyro_filtered_x_pg.freq, gyro_filtered_cmsis_x_pg.power)
display(f)
# Out:
# GLMakie.Screen(...)

# %% [markdown]
# # Data in circular buffer

# %%
# create circular buffer
buffer_len = m+1
cb = CircularBuffer{Float64}(buffer_len)

# to hold filtered output
gyro_filtered_x_cb = zeros(Float32, length(gyro_unfiltered_x))

# push first 3 elements of gyro data to the circular buffer
for i in 1:length(gyro_unfiltered_x)
    # push data sample 
    push!(cb, gyro_unfiltered_x[i])

    # apply filter to circular buffer 
    filtered_output = filt(chebyshev_filter, cb.buffer)

    gyro_filtered_x_cb[i] = filtered_output[buffer_len]
end

f = Figure()

ax1 = Axis(f[1, 1], title = "Gyro filtered", xlabel = "time", ylabel = "Amplitude")

lines!(ax1,  gyro_unfiltered_x)
lines!(ax1,  gyro_filtered_x_cb)

display(f)
# Out:
# GLMakie.Screen(...)

# %% [markdown]
# # Benchmarking

# %% [markdown]
# ## Using timev

# %%
# cmsis-dsp
@timev gyro_filtered_cmsis_f32_x = cmsisdsp.arm_biquad_cascade_df1_f32(biquadf32, gyro_unfiltered_x_f32);
# Out:
#   0.000142 seconds (34 allocations: 15.016 KiB)
# elapsed time (ns):  142286
# gc time (ns):       0
# bytes allocated:    15376
# pool allocs:        33
# non-pool GC allocs: 1
# minor collections:  0
# full collections:   0

# %%
# dsp.jl
@timev gyro_filtered_x = filt(chebyshev_filter, gyro_unfiltered_x);
# Out:
#   0.009255 seconds (201 allocations: 38.766 KiB)
# elapsed time (ns):  9255007
# gc time (ns):       0
# bytes allocated:    39696
# pool allocs:        200
# non-pool GC allocs: 0
# malloc() calls:     1
# free() calls:       0
# minor collections:  0
# full collections:   0

# %% [markdown]
# ### Using btime

# %%
# cmsis-dsp
@btime cmsisdsp.arm_biquad_cascade_df1_f32(biquadf32, gyro_unfiltered_x_f32);
# Out:
#   35.378 μs (34 allocations: 15.02 KiB)

# %%
# dsp.jl
@btime filt(chebyshev_filter, gyro_unfiltered_x);
# Out:
#   35.000 μs (201 allocations: 38.77 KiB)

# %% [markdown]
# ### Using benchmark

# %%
# cmsis-dsp
@benchmark cmsisdsp.arm_biquad_cascade_df1_f32(biquadf32, gyro_unfiltered_x_f32)
# Out:
# BenchmarkTools.Trial: 10000 samples with 1 evaluation.
#  Range (min … max):  35.249 μs …  51.370 ms  ┊ GC (min … max): 0.00% … 0.00%
#  Time  (median):     47.953 μs               ┊ GC (median):    0.00%
#  Time  (mean ± σ):   64.909 μs ± 526.777 μs  ┊ GC (mean ± σ):  0.79% ± 0.62%
#
#   █▃▆▇▄▂▂▂▂▁▁▁▁ ▁                                              ▁
#   █████████████████▇█▇▇▇▇▇▆▆▇▇▆▆▆▆▅▆▅▅▅▅▄▅▅▄▅▄▅▄▄▄▄▄▄▅▄▄▄▃▄▄▄▄ █
#   35.2 μs       Histogram: log(frequency) by time       301 μs <
#
#  Memory estimate: 15.02 KiB, allocs estimate: 34.

# %%
# dsp.jl
@benchmark filt(chebyshev_filter, gyro_unfiltered_x)
# Out:
# BenchmarkTools.Trial: 10000 samples with 1 evaluation.
#  Range (min … max):  34.511 μs …   3.883 ms  ┊ GC (min … max): 0.00% … 98.85%
#  Time  (median):     36.084 μs               ┊ GC (median):    0.00%
#  Time  (mean ± σ):   44.400 μs ± 110.949 μs  ┊ GC (mean ± σ):  6.43% ±  2.78%
#
#   █▅▁                                                          ▁
#   ███▇▆▆▆▄▅▆▇██▇▆▅▄▅▅▅▄▅▄▄▄▄▅▃▃▃▄▄▅▄▃▄▄▄▅▄▄▄▄▄▃▃▄▄▄▄▄▄▄▃▄▃▄▂▄▄ █
#   34.5 μs       Histogram: log(frequency) by time       175 μs <
#
#  Memory estimate: 38.77 KiB, allocs estimate: 201.

# %% [markdown]
# # Circular Buffer benchmarking

# %%
# create circular buffer
buffer_len = 30


function cb_test()
    cb = CircularBuffer{Float64}(buffer_len)
    
    # push elements of gyro data to the circular buffer
    for i in 1:length(gyro_unfiltered_x)
        # push data sample 
        push!(cb, gyro_unfiltered_x[i])
    end
end

# %%
cb
# Out:
# 30-element CircularBuffer{Float64}:
#   0.07450580596923828
#   0.13554096221923828
#   0.013470649719238281
#   0.07450580596923828
#   0.13554096221923828
#   0.13554096221923828
#   0.19657611846923828
#   0.13554096221923828
#  -0.04756450653076172
#  -0.2917051315307617
#  -0.2917051315307617
#  -0.10859966278076172
#   0.07450580596923828
#   ⋮
#   0.013470649719238281
#   0.07450580596923828
#   0.13554096221923828
#   0.07450580596923828
#   0.13554096221923828
#   0.13554096221923828
#   0.2576112747192383
#   0.13554096221923828
#   0.07450580596923828
#   0.013470649719238281
#  -0.10859966278076172
#  -0.16963481903076172
